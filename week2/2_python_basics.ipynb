# %% [markdown]
# <a href="https://colab.research.google.com/github/abbeyrknight/MIST4610GroupProject1/blob/main/week2/2_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python basics
#
#
# MIST5400 Fall 2026 - Instructor: Pearl (Peiyan) Yu
#
# ***

# %% [markdown]
# After you completed this notebook, **download the notebook as a ipynb file and submit in eLC assignment --> In-class exercise 1.**

# %% [markdown]
# ## 🎮 A quick heads-up
#
# This notebook has **interactive challenges** sprinkled in. You **don't** need to write any Python — for each one you'll read a small piece of code and **click** what you think it does. Correct answers earn points and build a streak. 🔥
#
# Just run the setup cell below once, then play along as you scroll.

# %%
# @title 🎮 Run me first! (makes the challenges below interactive — no coding needed)
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

class Quiz:
    def __init__(self):
        self.score = 0; self.streak = 0; self.best = 0; self.answered = set()
    def grade(self, qid, chosen, correct, points):
        if chosen == correct:
            first = qid not in self.answered
            if first:
                self.answered.add(qid); self.score += points
                self.streak += 1; self.best = max(self.best, self.streak)
            return True, first
        self.streak = 0
        return False, False
    def _scoreline(self):
        return ("<div style='font-family:system-ui;font-size:13px;color:#334155'>"
                "⭐ <b>%d</b> pts &nbsp;·&nbsp; 🔥 streak <b>%d</b> (best %d)"
                " &nbsp;·&nbsp; ✅ solved <b>%d</b></div>"
                % (self.score, self.streak, self.best, len(self.answered)))
    def ask(self, qid, question, options, correct, code=None, points=10,
            explain="", hint=""):
        head = widgets.HTML("<b>🧩 %s</b>" % question)
        parts = [head]
        if code:
            safe = code.replace("&", "&amp;").replace("<", "&lt;").replace(">", "&gt;")
            parts.append(widgets.HTML(
                "<pre style='background:#0f172a;color:#e2e8f0;padding:10px 12px;"
                "border-radius:8px;font-size:13px;overflow-x:auto'>%s</pre>" % safe))
        radio = widgets.RadioButtons(options=options, value=None,
                                     layout=widgets.Layout(width="auto"))
        btn = widgets.Button(description="Check answer", button_style="primary")
        out = widgets.Output()
        score = widgets.HTML(self._scoreline())
        def on_click(_):
            with out:
                clear_output()
                if radio.value is None:
                    print("👆 Pick an option first."); return
                ok, first = self.grade(qid, options.index(radio.value), correct, points)
                if ok:
                    print("✅ Correct!" + (" +%d pts" % points if first else " (already scored)"))
                    if explain: print("   " + explain)
                else:
                    print("❌ Not quite — take another look and try again.")
                    if hint: print("   💡 " + hint)
                score.value = self._scoreline()
        btn.on_click(on_click)
        parts += [radio, btn, out, score]
        display(widgets.VBox(parts))

quiz = Quiz()
print("✅ Ready! Answer each challenge by clicking an option and pressing Check.")
# Out:
# ✅ Ready! Answer each challenge by clicking an option and pressing Check.

# %% [markdown]
# This notebook shows examples of Python code, including built-in functions, packages and programming structures useful for Data Science and Business Analytics. This should be a quick tour so that you could understand python code (with some AI help), rather than teaching python formally. If you plan to code python intensively as an analyst, consider the intro to Python course. At the bottom there are some pointers to a few resources.
#
# Benefit of knowing a programming language: the direct benefit is the ability to build things. Also, learning to program changes how you think. It's a very structured language. It teaches to break big fuzzy problems into small precise steps. This computational thinking transfers to problem solving too.

# %% [markdown]
# ## Variables, operations, and other data types
# Variables are used to store data. Once assigned values, we can reuse the variables later.
# The data can be of a variety of types. Here're three types of data for example:
#
# -- **strings** for letter, words, and phrases
#
# -- **int** for integers
#
# -- **float** for real numbers stored as an approximation of an infinite decimal
#
# -- **boolean** logical TRUE or FALSE
#
# The Python character for **variable assignment** is the equal sign (=). Let's create three variables, one of each type, with 3 different names:

# %%
some_integer = 5
some_float = 7.12
some_string = "Student"

# %% [markdown]
# We can **print** out these variables. Remember we need to run the previous cell first!

# %%
print (some_integer)
print (some_float)
print (some_string)
# Out:
# 5
# 7.12
# Student

# %% [markdown]
# What if I want to print some text and then some numbers? One easy way to do this is to realize that printing will always **want** string data.
#
# If you have data that is not a string (like an integer or float), you can **convert** it to a string:

# %%
print ("My integer is " + str(some_integer) + ".")
print ("My float converted into integer is " + str( int(some_float) ) + ".")
# Out:
# My integer is 5.
# My float converted into integer is 7.

# %% [markdown]
# What else can we do with our variables? We can do basic math: **operations**.
# The operations (e.g. "+") will  behave differently depending on the type:

# %%
# plus sign (+) will add two integers
int1 = 6
int2 = 4
print ("sum of ints = ",int1 + int2)
# Out:
# sum of ints =  10

# %%
# plus sign (+) will concatenate two strings
str1= 'Taylor'
str2 = ' Swift'
print ("sum of strings =",str1 + str2)
# Out:
# sum of strings = Taylor Swift

# %% [markdown]
# We can also store the result of operations as a new variable and print it:

# %%
some_integer = 10
some_float = 7.12
my_sum = some_integer + some_float

print ("Sum variable: " + str( my_sum ))
# Out:
# Sum variable: 17.12

# %% [markdown]
# ### 🧩 Challenge: types & printing
# Read the code, then click what it prints.

# %%
quiz.ask(
    'types_sum',
    'What does this code print?',
    ['17.12', '17', '1712', 'an error'],
    0,
    code='some_integer = 10\nsome_float = 7.12\nmy_sum = some_integer + some_float\nprint(my_sum)',
    points=10,
    explain='An int + a float gives a float, so you get 17.12.',
    hint='What type do you get when you add a whole number and a decimal?',
)
# Out:
# VBox(children=(HTML(value='<b>🧩 What does this code print?</b>'), HTML(value="<pre style='background:#0f172a;c…

# %% [markdown]
# There are also other **data structures**:
#
# **Lists** will be the most common ones we will use, they are simply collections of data and can contain different data types.  Lists are created with square brackets `[]` and can be accessed via an index:

# %%
beatles = ["John", "Paul", "George","Ringo"]
# printing the whole array
print(beatles)
# Out:
# ['John', 'Paul', 'George', 'Ringo']

# %%
# printing the first element of that array, at index 0
print(beatles[0])
# access the second element, at index 1
print(beatles[1])
# access the last element, at index -1
print(beatles[-1])
# Out:
# John
# Paul
# Ringo

# %% [markdown]
# ### 🧩 Challenge: picking items from a list

# %%
quiz.ask(
    'beatles_neg',
    'What does this print?',
    ['George', 'Ringo', 'Paul', "['George', 'Ringo']"],
    0,
    code='beatles = ["John", "Paul", "George", "Ringo"]\nprint(beatles[-2])',
    points=10,
    explain='Index -1 is the last item (Ringo), so -2 is the second-to-last: George.',
    hint='Negative indexes count backwards from the end.',
)
# Out:
# VBox(children=(HTML(value='<b>🧩 What does this print?</b>'), HTML(value='<pre style=\'background:#0f172a;color…

# %%
# We could also access "slices" of a list

alist = [37, 41, 43, 45, 47, 49]

# a[start:end] # items start through end-1
print(alist[2:4])

# alist[start:]    # items start through the rest of the array
print(alist[3:])

# alist[:end]      # items from the beginning through end-1
print(alist[:4])
# Out:
# [43, 45]
# [45, 47, 49]
# [37, 41, 43, 45]

# %% [markdown]
# Adding things to the end of the list is "appending" them:

# %%
alist.append(500)
print (alist)
# Out:
# [37, 41, 43, 45, 47, 49, 500]

# %% [markdown]
# There are other data structures such as **dictionaries** (key-value pairs)
# and **sets** (unordered list of items). Don't worry if you can't remember all these. Just know that there're different structures to store data.

# %%
some_dictionary = {'student1': 'A+', 'student2': 'B-', 'student3': 'A-'}
print ("This is a dictionary:  " , some_dictionary )
# Out:
# This is a dictionary:   {'student1': 'A+', 'student2': 'B-', 'student3': 'A-'}

# %% [markdown]
# How can we retrieve an element (**VALUE**) of a _dictionary_ ?  Use its **"KEY"** !!

# %%
print (some_dictionary['student1'])
# Out:
# A+

# %% [markdown]
# Sets are just lists but the elements don't have orders or indexes.

# %%
some_set = set( ["aaron","juan","anthony","giancarlo",29] )
print ("This is a set:  " + str( some_set ))
# Out:
# This is a set:  {'anthony', 'aaron', 'juan', 29, 'giancarlo'}

# %% [markdown]
# For more customizable string creation and printing, python also includes rich formatting capability that may be familiar to developers of other high-level programming language. Some examples are below. In a nutshell, one adds placeholders to the string being constructed. These placeholders always start with a `%` followed by some additional information that determines how the data will be formatted. After the string, another `%` is used, followed by the acutal data that is to be inserted in the prior placeholders. The full capabilities of python string formatting are beyond the scope of this primer, for more info, please consult the [offical documentation](https://docs.python.org/2/library/stdtypes.html#string-formatting).

# %%
print ("generic %s formatting, equivalent to the str() functionality seen earlier" % "STRING")
print ("an example with zero padding an integer %003d and multiple %s" % (5, "PLACEHOLDERS"))
print ("often one wants to truncate the precision when displaying floats %.3f" % 3.1415926536)
# Out:
# generic STRING formatting, equivalent to the str() functionality seen earlier
# an example with zero padding an integer 005 and multiple PLACEHOLDERS
# often one wants to truncate the precision when displaying floats 3.142

# %% [markdown]
# ## Create functions

# %% [markdown]
# Functions are essentially blocks of code that you can reference by name. Functions allow us to execute predefined operations and to define our own operations that will be available later.  They encapsulate procedures. You should define functions for steps that you anticipate using multiple times. If you only perform a series of steps once or twice, you probably do not need to define a function.
#
# (*If you haven't thought this through before, consider the drawback of repeated code: what if later you realize that you need to fix something in that code block.  You'd have to go through and fix it everywhere.*)
#
# Functions are created using the **def** statement, following the same indented code structure as a conditional or a loop.
#
# ```
# def function_name(inputs):
#     statements
#     return object(s) # optional
# ```
#
# For example, consider having to calculate the area of a circle.

# %%
## define a function to calculate the area of a circle
def area_of_a_circle(radius):
    area = 3.1416 * radius ** 2
    return area

# %%
## call a function
circle_area = area_of_a_circle(5)
print ("Area of a circle with radius 5 is: " + str( circle_area))
# Out:
# Area of a circle with radius 5 is: 78.53999999999999

# %% [markdown]
# Can you see what is going on here? My function that I helpfully named `"area_of_a_circle"` takes one **argument** that we will call radius. It then uses this radius to get the area and then *returns* it. Now, whenever I want to get the area of some circle, I simply call `area_of_a_circle()` and place the radius in the middle of the parentheses.

# %% [markdown]
# ### 🧩 Challenge: functions

# %%
quiz.ask(
    'rect_area',
    'What does this print?',
    ['20', '9', '54', 'an error'],
    0,
    code='def area_of_rectangle(length, width):\n    return length * width\n\nprint(area_of_rectangle(5, 4))',
    points=10,
    explain='The function returns length * width = 5 * 4 = 20.',
    hint='Follow what the function returns, then what gets printed.',
)
# Out:
# VBox(children=(HTML(value='<b>🧩 What does this print?</b>'), HTML(value="<pre style='background:#0f172a;color:…

# %% [markdown]
# ##  Loops / iterations

# %% [markdown]
# For data analysis we do a lot of repetitive things. This doesn't mean we need to do a ton of copy and pasting, though. We can use **loops** to make this easy. Loops are used to perform a series of steps repeatedly. As a very simple example, what if we wanted to square each number from 1 to 5?

# %%
for number in [1, 2, 3, 4, 5]:
    print (number * number)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# Let's use the function we did before. Remember this is a function that can only be used in **this notebook**
#
# ( unless we write a **"script"** file, but we'll see that later... ):

# %%
for number in [1, 2, 3, 4, 5]:
    print ("Area of circle with radius " , number , " is: ", area_of_a_circle(number) )
# Out:
# Area of circle with radius  1  is:  3.1416
# Area of circle with radius  2  is:  12.5664
# Area of circle with radius  3  is:  28.2744
# Area of circle with radius  4  is:  50.2656
# Area of circle with radius  5  is:  78.53999999999999

# %% [markdown]
# **While** loops use the while keyword, a condition, and the loop body.  The loop continues until the condition is broken.

# %% [markdown]
# **Exercise**: Can you figure out what this piece of code does?

# %%
a = 1

while a < 100:
    a = a + 10

print (a)
# Out:
# 101

# %% [markdown]
# ## Conditionals and comparisons

# %% [markdown]
# Sometimes we need to check something before deciding what to do next.
#
# **if** statements are the most common type of conditional. They allow you to execute a different set of statements under different conditions.
#
# For example,

# %%
def is_best_prof(name):
    if name == "Pearl":
        return True
    else:
        return False

# %%
is_best_prof("Pearl")
# Out:
# True

# %%
is_best_prof("John")
# Out:
# False

# %% [markdown]
# **Exercise**: Can you describe what this piece of code is doing?

# %%
quiz.ask(
    'if_print',
    'The `is_best_prof` function returns True only for "Pearl". What does this print?',
    ["You're going to have a great semester!", 'Well, make the best of it!', 'True', 'nothing'],
    0,
    code='my_prof = "Pearl"\n\nif is_best_prof(my_prof):\n    print("You\'re going to have a great semester!")\nelse:\n    print("Well, make the best of it!")',
    points=10,
    explain='my_prof is "Pearl", so the condition is True and the first message prints.',
    hint='What does is_best_prof("Pearl") return — and which branch runs then?',
)
# Out:
# VBox(children=(HTML(value='<b>🧩 The `is_best_prof` function returns True only for "Pearl". What does this prin…

# %% [markdown]
# You see in that last one how we have a conditional in the cell, and then call a function that has a conditional inside it?
#
# Let's put a whole bunch of these things together:

# %% [markdown]
# **Exercise**: Can you describe what this piece of code is doing?

# %%
quiz.ask(
    'loop_count',
    'How many lines does this loop print in total?',
    ['4', '2', '8', '1'],
    0,
    code='my_profs = ["John", "Paul", "Pearl", "Ringo"]\nfor prof in my_profs:\n    print("I\'m taking a course with", prof)',
    points=10,
    explain='The loop runs once per name in the list — 4 names, so 4 lines.',
    hint='A for loop repeats its body once for each item in the list.',
)
# Out:
# VBox(children=(HTML(value='<b>🧩 How many lines does this loop print in total?</b>'), HTML(value='<pre style=\'…

# %% [markdown]
# As we can see here, we made **comparison** of names with the "equal" operation  (==).  Remember ... it's == not just = !
#
# Other comparisons:
#
# - strictly less than  <
# - less than or equal  <=
# - strictly greater than  >
# - greater than or equal  >=
# - not equal  !=
# - object identity  "is"
# - negated object identity "is not"
#
# What if we want to compare more than one element?
# We should include logical operations such as:
#
# - "and", also known as "&"
# - "or", also known as "|"
#
# Let's see if you can guess my age with this function!!

# %%
def is_my_age(age_argument):
    if age_argument < 20:
        return "Of course not!"
    elif (age_argument >= 20) & (age_argument <= 40):
        return "Maybe.."
    elif age_argument > 40:
        return "Don't even think about it!"

# %%
print (is_my_age(10))
# Out:
# Of course not!

# %% [markdown]
# ### 🧩 Challenge: if / elif / else

# %%
quiz.ask(
    'is_my_age',
    'Given this function, what does is_my_age(23) return?',
    ['"Maybe.."', '"Of course not!"', '"Don\'t even think about it!"', '23'],
    0,
    code='def is_my_age(age):\n    if age < 20:\n        return "Of course not!"\n    elif age <= 40:\n        return "Maybe.."\n    else:\n        return "Don\'t even think about it!"\n\nprint(is_my_age(23))',
    points=10,
    explain='23 is not < 20, but it is <= 40, so the elif branch returns "Maybe..".',
    hint="Check each condition top to bottom. Which is the first one that's True for 23?",
)
# Out:
# VBox(children=(HTML(value='<b>🧩 Given this function, what does is_my_age(23) return?</b>'), HTML(value='<pre s…

# %% [markdown]
# ## 🤖 Let Gemini write the code for you
#
# You're an **analyst**, not a programmer — so a huge part of this course is learning to get **GenAI to write code for you**. Good news: Colab has **Gemini built in**, and you can call it from a cell with **no API key and no setup**. Run the cell below to see it write code on demand.
#
# > If your school account has this turned off, the cell will say so — you can still use the **Gemini side-panel** (the ✨ button) or the *“Generate”* link inside an empty code cell.

# %% [markdown]
# ### 🧩 Challenge: prompting Gemini well

# %%
quiz.ask(
    'gemini_prompt',
    'You have a table `df` of sales and want a bar chart of total sales per month. Which prompt is most likely to get Gemini to give you what you want?',
    ['Using the dataframe df, plot a bar chart of total sales for each month, with month on the x-axis and sales on the y-axis.', 'make chart', 'sales stuff', 'do the thing with the data'],
    0,
    points=15,
    explain='Good prompts are specific: they name your data (df), say exactly what you want (bar chart of total sales per month), and describe the layout (axes).',
    hint='Which one tells Gemini WHAT data to use and EXACTLY what to make?',
)
# Out:
# VBox(children=(HTML(value='<b>🧩 You have a table `df` of sales and want a bar chart of total sales per month. …

# %%
# @title 🏁 Your score so far — run this anytime
from IPython.display import HTML, display
display(HTML(quiz._scoreline()))
print("Solved %d challenges. Scroll up and beat any you missed to climb the score!"
      % len(quiz.answered))
# Out:
# <div style='font-family:system-ui;font-size:13px;color:#334155'>⭐ <b>75</b> pts &nbsp;·&nbsp; 🔥 streak <b>7</b> (best 7) &nbsp;·&nbsp; ✅ solved <b>7</b></div>
# Solved 7 challenges. Scroll up and beat any you missed to climb the score!

# %% [markdown]
# **Remember to download the run-through notebook as a ipynb file and submit in eLC assignment --> In-class exercise 1.**

# %% [markdown]
# ## Help, help, and more help!

# %% [markdown]
# Please dont get discouraged if you are stuck. This is how professional programmers work every day.  Try and do it yourself first, and then reach out for other resources.  Google your problem and it will likely take you to posts at [StackOverflow](http://stackoverflow.com), a popular programming question and answer site, with an extremely rich repository of solutions to problems that people have encountered.  It is likely that someone has asked the question you need answering and has posted a solution.
#
# It is also easy to ask a question of GenAI tools like ChatGPT or Gemini (which is built right into Colab).  These will often get you the correct answer, but I caution against simple cut-and-paste of the solution. Sometimes the code runs through but gives you the wrong thing. Sometimes it doesn't give you the simplest solution. Try and work your way through the code and understand the answer, and even ask ChatGPT questions like "why is that line in the code?".  Typing the code in instead of cut/paste can help you with the learning process.
#
# Programming can be frustrating. It's natural to get stuck or frustrated from time to time, even with the incredible resources that are now available. Take breaks, ask others for help, and be kind to yourself!
#
# ---
#
# For refreshers, here are some resources:
#
# - Courses at [python.org](https://docs.python.org/3/tutorial/)
# - Online courses at [datacamp.com](https://www.datacamp.com/)
# - [Codecademy's Python Course](https://www.codecademy.com/learn/learn-python-3). Working though this class will give you a _great_ foundation for Python.
# - [Python for Data Analysis](https://www.amazon.com/Python-Data-Analysis-Wrangling-IPython-ebook/dp/B009NLMB8Q/ref=mt_kindle?_encoding=UTF8&me=) was the book that Prof. Foster suggested to prior iterations of this course. You can take a look at the chapters: Preliminaries, Introductory Examples (e.g. "Counting Time Zones with pandas”), IPython (page 46 to 62) and specially, Pandas--one of the main Python packages for data analysis.  We will work with Pandas in class.
# - [Pandas Cookbook](https://www.amazon.com/Pandas-Cookbook-Scientific-Computing-Visualization/dp/1784393878) is another great resource to learn Pandas. It has lots of practice problems with detailed solutions in IPython notebooks.
